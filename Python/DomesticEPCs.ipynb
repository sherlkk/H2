# %%
import os
import re
import json
import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns
# Out:
# /Users/xuerongrong/opt/anaconda3/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
boros = gpd.read_file('data/boundary.gpkg')

# %%
boros.plot(figsize=(8,8), color='lightgrey', alpha=0.8)
# Out:
# <AxesSubplot:>

# %%
domepc = pd.read_csv('data/certificates_domestic.csv', low_memory=False)

# %%
domepc.shape
# Out:
# (136866, 92)

# %%
domepc.columns
# Out:
# Index(['LMK_KEY', 'ADDRESS1', 'ADDRESS2', 'ADDRESS3', 'POSTCODE',
#        'BUILDING_REFERENCE_NUMBER', 'CURRENT_ENERGY_RATING',
#        'POTENTIAL_ENERGY_RATING', 'CURRENT_ENERGY_EFFICIENCY',
#        'POTENTIAL_ENERGY_EFFICIENCY', 'PROPERTY_TYPE', 'BUILT_FORM',
#        'INSPECTION_DATE', 'LOCAL_AUTHORITY', 'CONSTITUENCY', 'COUNTY',
#        'LODGEMENT_DATE', 'TRANSACTION_TYPE', 'ENVIRONMENT_IMPACT_CURRENT',
#        'ENVIRONMENT_IMPACT_POTENTIAL', 'ENERGY_CONSUMPTION_CURRENT',
#        'ENERGY_CONSUMPTION_POTENTIAL', 'CO2_EMISSIONS_CURRENT',
#        'CO2_EMISS_CURR_PER_FLOOR_AREA', 'CO2_EMISSIONS_POTENTIAL',
#        'LIGHTING_COST_CURRENT', 'LIGHTING_COST_POTENTIAL',
#        'HEATING_COST_CURRENT', 'HEATING_COST_POTENTIAL',
#        'HOT_WATER_COST_CURRENT', 'HOT_WATER_COST_POTENTIAL',
#        'TOTAL_FLOOR_AREA', 'ENERGY_TARIFF', 'MAINS_GAS_FLAG', 'FLOOR_LEVEL',
#        'FLAT_TOP_STOREY', 'FLAT_STOREY_COUNT', 'MAIN_HEATING_CONTROLS',
#        'MULTI_GLAZE_PROPORTION', 'GLAZED_TYPE', 'GLAZED_AREA',
#        'EXTENSION_COUNT', 'NUMBER_HABITABLE_ROOMS', 'NUMBER_HEATED_ROOMS',
#        'LOW_ENERGY_LIGHTING', 'NUMBER_OPEN_FIREPLACES', 'HOTWATER_DESCRIPTION',
#        'HOT_WATER_ENERGY_EFF', 'HOT_WATER_ENV_EFF', 'FLOOR_DESCRIPTION',
#        'FLOOR_ENERGY_EFF', 'FLOOR_ENV_EFF', 'WINDOWS_DESCRIPTION',
#        'WINDOWS_ENERGY_EFF', 'WINDOWS_ENV_EFF', 'WALLS_DESCRIPTION',
#        'WALLS_ENERGY_EFF', 'WALLS_ENV_EFF', 'SECONDHEAT_DESCRIPTION',
#        'SHEATING_ENERGY_EFF', 'SHEATING_ENV_EFF', 'ROOF_DESCRIPTION',
#        'ROOF_ENERGY_EFF', 'ROOF_ENV_EFF', 'MAINHEAT_DESCRIPTION',
#        'MAINHEAT_ENERGY_EFF', 'MAINHEAT_ENV_EFF', 'MAINHEATCONT_DESCRIPTION',
#        'MAINHEATC_ENERGY_EFF', 'MAINHEATC_ENV_EFF', 'LIGHTING_DESCRIPTION',
#        'LIGHTING_ENERGY_EFF', 'LIGHTING_ENV_EFF', 'MAIN_FUEL',
#        'WIND_TURBINE_COUNT', 'HEAT_LOSS_CORRIDOR', 'UNHEATED_CORRIDOR_LENGTH',
#        'FLOOR_HEIGHT', 'PHOTO_SUPPLY', 'SOLAR_WATER_HEATING_FLAG',
#        'MECHANICAL_VENTILATION', 'ADDRESS', 'LOCAL_AUTHORITY_LABEL',
#        'CONSTITUENCY_LABEL', 'POSTTOWN', 'CONSTRUCTION_AGE_BAND',
#        'LODGEMENT_DATETIME', 'TENURE', 'FIXED_LIGHTING_OUTLETS_COUNT',
#        'LOW_ENERGY_FIXED_LIGHT_COUNT', 'UPRN', 'UPRN_SOURCE'],
#       dtype='object')

# %%
coo=['LMK_KEY', 'ADDRESS1', 'ADDRESS2', 'ADDRESS3', 
       'POTENTIAL_ENERGY_RATING', 'CURRENT_ENERGY_EFFICIENCY',
       'POTENTIAL_ENERGY_EFFICIENCY', 'PROPERTY_TYPE', 'BUILT_FORM',
       'INSPECTION_DATE', 'LOCAL_AUTHORITY', 'CONSTITUENCY', 'COUNTY',
       'LODGEMENT_DATE', 'TRANSACTION_TYPE', 'ENVIRONMENT_IMPACT_CURRENT',
       'ENVIRONMENT_IMPACT_POTENTIAL', 'ENERGY_CONSUMPTION_CURRENT',
       'ENERGY_CONSUMPTION_POTENTIAL', 'CO2_EMISSIONS_CURRENT',
       'CO2_EMISS_CURR_PER_FLOOR_AREA', 'CO2_EMISSIONS_POTENTIAL',
       'LIGHTING_COST_CURRENT', 'LIGHTING_COST_POTENTIAL',
       'HEATING_COST_CURRENT', 'HEATING_COST_POTENTIAL',
       'HOT_WATER_COST_CURRENT', 'HOT_WATER_COST_POTENTIAL',
       'TOTAL_FLOOR_AREA', 'ENERGY_TARIFF', 'FLOOR_LEVEL',
       'FLAT_TOP_STOREY', 'FLAT_STOREY_COUNT', 'MAIN_HEATING_CONTROLS',
       'MULTI_GLAZE_PROPORTION', 'GLAZED_TYPE', 'GLAZED_AREA',
       'EXTENSION_COUNT', 'NUMBER_HABITABLE_ROOMS', 'NUMBER_HEATED_ROOMS',
       'LOW_ENERGY_LIGHTING', 'NUMBER_OPEN_FIREPLACES', 'HOTWATER_DESCRIPTION',
       'HOT_WATER_ENERGY_EFF', 'HOT_WATER_ENV_EFF', 'FLOOR_DESCRIPTION',
       'FLOOR_ENERGY_EFF', 'FLOOR_ENV_EFF', 'WINDOWS_DESCRIPTION',
       'WINDOWS_ENERGY_EFF', 'WINDOWS_ENV_EFF', 'WALLS_DESCRIPTION',
       'WALLS_ENERGY_EFF', 'WALLS_ENV_EFF', 'SECONDHEAT_DESCRIPTION',
       'SHEATING_ENERGY_EFF', 'SHEATING_ENV_EFF', 'ROOF_DESCRIPTION',
       'ROOF_ENERGY_EFF', 'ROOF_ENV_EFF',
       'MAINHEAT_ENERGY_EFF', 'MAINHEAT_ENV_EFF', 'MAINHEATCONT_DESCRIPTION',
       'MAINHEATC_ENERGY_EFF', 'MAINHEATC_ENV_EFF', 'LIGHTING_DESCRIPTION',
       'LIGHTING_ENERGY_EFF', 'LIGHTING_ENV_EFF',
       'WIND_TURBINE_COUNT', 'HEAT_LOSS_CORRIDOR', 'UNHEATED_CORRIDOR_LENGTH',
       'FLOOR_HEIGHT', 'PHOTO_SUPPLY', 'SOLAR_WATER_HEATING_FLAG',
       'MECHANICAL_VENTILATION', 'ADDRESS', 'LOCAL_AUTHORITY_LABEL',
       'CONSTITUENCY_LABEL', 'POSTTOWN', 'CONSTRUCTION_AGE_BAND',
       'LODGEMENT_DATETIME', 'TENURE', 'FIXED_LIGHTING_OUTLETS_COUNT',
       'LOW_ENERGY_FIXED_LIGHT_COUNT', 'UPRN_SOURCE']

# %%
domepc = domepc.drop(coo, axis=1)
domepc.columns
# Out:
# Index(['POSTCODE', 'BUILDING_REFERENCE_NUMBER', 'CURRENT_ENERGY_RATING',
#        'MAINS_GAS_FLAG', 'MAINHEAT_DESCRIPTION', 'MAIN_FUEL', 'UPRN'],
#       dtype='object')

# %%
domepc.head(3)
# Out:
#   POSTCODE  BUILDING_REFERENCE_NUMBER CURRENT_ENERGY_RATING MAINS_GAS_FLAG  \
# 0   W2 6DE                 5917607278                     C              Y
# 1   W9 1LF                 7273449668                     D              Y
# 2  W1G 8TJ                 9110917378                     B              Y
#
#                        MAINHEAT_DESCRIPTION  \
# 0           Boiler and radiators, mains gas
# 1           Boiler and radiators, mains gas
# 2  Boiler and underfloor heating, mains gas
#
#                                            MAIN_FUEL          UPRN
# 0                          mains gas (not community)  1.003357e+10
# 1  mains gas - this is for backwards compatibilit...  1.000228e+11
# 2                          mains gas (not community)  1.003363e+10

# %%
total = domepc.isnull().sum().sort_values(ascending=False)
percent = (domepc.isnull().sum()/domepc.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(5)
# Out:
#                       Total   Percent
# MAINS_GAS_FLAG        13542  0.098943
# UPRN                  13301  0.097183
# MAIN_FUEL              1002  0.007321
# MAINHEAT_DESCRIPTION      1  0.000007
# POSTCODE                  0  0.000000

# %%
#it removes duplicate rows based on all columns
domepc.drop_duplicates(inplace=True)

# %%
domepc.shape
# Out:
# (132076, 7)

# %%
print(domepc['UPRN'].nunique())
print(domepc['BUILDING_REFERENCE_NUMBER'].nunique())
# Out:
# 86576
# 107107

# %%
uprncsv = pd.read_csv('data/osopenuprn_202206.csv')

# %%
uprncsv.sample(3)
# Out:
#                   UPRN  X_COORDINATE  Y_COORDINATE   LATITUDE  LONGITUDE
# 22202314   10095831680     388801.37     105250.39  50.846656  -2.160429
# 28144963  100040799561     403605.00      92452.00  50.731663  -1.950277
# 18260441   10033580322     529231.00     180878.00  51.512059  -0.139081

# %%
epcuprn = pd.merge(domepc, uprncsv, how="left",on='UPRN')
print(epcuprn.shape)
# Out:
# (132076, 11)

# %%
total = epcuprn.isnull().sum().sort_values(ascending=False)
percent = (domepc.isnull().sum()/epcuprn.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                            Total   Percent
# MAINS_GAS_FLAG             13166  0.099685
# X_COORDINATE               12873       NaN
# Y_COORDINATE               12873       NaN
# LATITUDE                   12873       NaN
# LONGITUDE                  12873       NaN
# UPRN                       12872  0.097459
# MAIN_FUEL                    996  0.007541
# MAINHEAT_DESCRIPTION           1  0.000008
# POSTCODE                       0  0.000000
# BUILDING_REFERENCE_NUMBER      0  0.000000
# CURRENT_ENERGY_RATING          0  0.000000

# %%
print(domepc['UPRN'].nunique())
print(epcuprn['UPRN'].nunique())
# Out:
# 86576
# 86576

# %%
naepcuprn = epcuprn.dropna(subset=['LATITUDE', 'LONGITUDE'])

# %%
print(naepcuprn.shape)
# Out:
# (119203, 11)

# %%
print(naepcuprn['BUILDING_REFERENCE_NUMBER'].nunique())
print(naepcuprn['UPRN'].nunique())
# Out:
# 96469
# 86575

# %%
geoepcuprn = gpd.GeoDataFrame(naepcuprn, 
      geometry=gpd.points_from_xy(naepcuprn['LONGITUDE'], naepcuprn['LATITUDE'], crs='epsg:4326'))
geoepcuprn = geoepcuprn.to_crs('epsg:27700')

# %%
geoepcuprn.sample(3)
# Out:
#        POSTCODE  BUILDING_REFERENCE_NUMBER CURRENT_ENERGY_RATING  \
# 52437    W2 4SN                 1717311578                     E
# 74556    W9 1PF                 1252179868                     C
# 19734  WC2B 4AH                 5276764678                     C
#
#       MAINS_GAS_FLAG             MAINHEAT_DESCRIPTION  \
# 52437              Y  Boiler and radiators, mains gas
# 74556              N  Boiler and radiators, mains gas
# 19734              Y  Boiler and radiators, mains gas
#
#                        MAIN_FUEL          UPRN  X_COORDINATE  Y_COORDINATE  \
# 52437  mains gas (not community)  1.000228e+11      525729.0      180865.0
# 74556  mains gas (not community)  1.000228e+11      525777.0      182999.0
# 19734  mains gas (not community)  1.003355e+10      530517.0      181133.0
#
#         LATITUDE  LONGITUDE                       geometry
# 52437  51.512731  -0.189524  POINT (525730.692 180865.206)
# 74556  51.531899  -0.188072  POINT (525778.718 182999.257)
# 19734  51.514055  -0.120465  POINT (530518.768 181133.222)

# %%
geoepcuprn = geoepcuprn.drop(geoepcuprn[(geoepcuprn.LONGITUDE > -0.1)].index, axis=0)
print(f"Data frame is {geoepcuprn.shape[0]:,} x {geoepcuprn.shape[1]}")
print(f"Number of unique UPRN is {geoepcuprn['UPRN'].nunique()}")
# Out:
# Data frame is 119,192 x 12
# Number of unique UPRN is 86569

# %%
ax = geoepcuprn.plot(column='MAINS_GAS_FLAG',cmap='cividis', markersize=1, legend=True, alpha=0.9, figsize=(20,20))
#green.plot(color='olive', alpha=0.6, ax=ax)
boros.plot(color='lightgrey', alpha=0.3, ax=ax)
# Out:
# <AxesSubplot:>

# %%
count = geoepcuprn.groupby('MAIN_FUEL')['UPRN'].count()
print("Frequency of MAIN_FUEL:\n", count)
# Out:
# Frequency of MAIN_FUEL:
#  MAIN_FUEL
# B30D (community)                                                                                    12
# B30K (not community)                                                                                 1
# Electricity: electricity, unspecified tariff                                                      1373
# Gas: mains gas                                                                                     116
# INVALID!                                                                                            75
# LPG (community)                                                                                     18
# LPG (not community)                                                                                 96
# LPG - this is for backwards compatibility only and should not be used                               62
# NO DATA!                                                                                          6022
# To be used only when there is no heating/hot-water system                                          613
# To be used only when there is no heating/hot-water system or data is from a community network       62
# anthracite                                                                                           1
# appliances able to use mineral oil or liquid biofuel                                                 1
# biogas (community)                                                                                   3
# biogas - landfill - this is for backwards compatibility only and should not be used                  4
# biomass (community)                                                                                  6
# biomass - this is for backwards compatibility only and should not be used                            3
# bottled LPG                                                                                          8
# coal (community)                                                                                     1
# dual fuel - mineral + wood                                                                           7
# electricity (community)                                                                            620
# electricity (not community)                                                                      12658
# electricity - this is for backwards compatibility only and should not be used                     5875
# from heat network data (community)                                                                   7
# heat from boilers that can use mineral oil or biodiesel (community)                                  1
# heat from boilers using biodiesel from any biomass source (community)                                4
# house coal (not community)                                                                           1
# house coal - this is for backwards compatibility only and should not be used                         3
# mains gas (community)                                                                            17886
# mains gas (not community)                                                                        43369
# mains gas - this is for backwards compatibility only and should not be used                      29189
# oil (community)                                                                                    254
# oil (not community)                                                                                 17
# oil - this is for backwards compatibility only and should not be used                              318
# smokeless coal                                                                                       9
# waste combustion (community)                                                                         3
# waste combustion - this is for backwards compatibility only and should not be used                   2
# wood logs                                                                                            1
# Name: UPRN, dtype: int64

# %%
count = geoepcuprn.groupby('MAINHEAT_DESCRIPTION')['UPRN'].count()
pd.set_option('display.max_rows', None)  # or 1000
print("Frequency of MAINHEAT_DESCRIPTION:\n", count)
# Out:
# Frequency of MAINHEAT_DESCRIPTION:
#  MAINHEAT_DESCRIPTION
# Air source heat pump , electric                                                                          4
# Air source heat pump fan coil units, electric                                                           18
# Air source heat pump fan coil units, electric, Electric underfloor heating, underfloor, electric         1
# Air source heat pump, , electric                                                                         4
# Air source heat pump, Fan coil units, electric                                                          52
# Air source heat pump, Systems with radiators, electric                                                   7
# Air source heat pump, Underfloor heating and radiators, pipes in insulated timber floor, electric        1
# Air source heat pump, Underfloor heating, pipes in insulated timber floor, electric                     16
# Air source heat pump, Underfloor heating, pipes in screed above insulation, electric                    27
# Air source heat pump, Warm air, electric                                                                14
# Air source heat pump, electric                                                                          60
# Air source heat pump, fan coil units, electric                                                          22
# Air source heat pump, mains gas                                                                          1
# Air source heat pump, radiators, electric                                                              107
# Air source heat pump, underfloor, electric                                                             307
# Air source heat pump, underfloor, electric, Electric underfloor heating                                  2
# Air source heat pump, underfloor, mains gas                                                              1
# Air source heat pump, warm air, electric                                                              1127
# Air source heat pump, warm air, electric, Electric underfloor heating                                   14
# Air source heat pump, warm air, electric, Room heaters, electric                                         1
# Air source heat pump, warm air, electricity                                                              1
# Air source heat pump, warm air, mains gas                                                                8
# Boiler & underfloor, LPG                                                                                 8
# Boiler & underfloor, electric                                                                           13
# Boiler & underfloor, mains gas                                                                         285
# Boiler and , mains gas                                                                                   1
# Boiler and radiators                                                                                     1
# Boiler and radiators,                                                                                    2
# Boiler and radiators, B30K                                                                               1
# Boiler and radiators, LPG                                                                              136
# Boiler and radiators, coal                                                                               1
# Boiler and radiators, electric                                                                        1763
# Boiler and radiators, electricity (24-hr heating tariff)                                                 1
# Boiler and radiators, heat from boilers - mains gas                                                      1
# Boiler and radiators, mains gas                                                                      62330
# Boiler and radiators, mains gas, Air source heat pump, underfloor, electric                              3
# Boiler and radiators, mains gas, Air source heat pump, warm air, electric                                1
# Boiler and radiators, mains gas, Boiler and radiators, mains gas                                        15
# Boiler and radiators, mains gas, Boiler and underfloor heating, mains gas                                3
# Boiler and radiators, mains gas, Electric underfloor heating                                             6
# Boiler and radiators, mains gas, Room heaters, electric                                                  1
# Boiler and radiators, oil                                                                                6
# Boiler and radiators, |Bwyler a rheiddiaduron, |mains gas|nwy prif gyflenwad                             1
# Boiler and underfloor heating, LPG                                                                       8
# Boiler and underfloor heating, electric                                                                212
# Boiler and underfloor heating, electric, Boiler and underfloor heating, electric                         1
# Boiler and underfloor heating, electricity (24-hr heating tariff)                                        2
# Boiler and underfloor heating, mains gas                                                              2145
# Boiler and underfloor heating, mains gas, Boiler and radiators, mains gas                                1
# Boiler and underfloor heating, mains gas, Boiler and underfloor heating, mains gas                       5
# Boiler and underfloor heating, mains gas, Community scheme                                               1
# Boiler and underfloor heating, mains gas, Electric underfloor heating                                    3
# Boiler and underfloor heating, oil                                                                       2
# Boiler, mains gas                                                                                        2
# Community heat pump, electric                                                                           10
# Community scheme                                                                                     30837
# Community scheme with CHP                                                                              818
# Community scheme with CHP and electric                                                                   3
# Community scheme with CHP and mains gas                                                                 10
# Community scheme with CHP, mains gas                                                                   303
# Community scheme, Air source heat pump, underfloor, electric                                             1
# Community scheme, LPG                                                                                    1
# Community scheme, Room heaters, electric                                                                 3
# Community scheme, mains gas                                                                            769
# Community scheme, mains gas and biomass                                                                 41
# Community scheme, oil                                                                                   22
# Community scheme, radiators, mains gas                                                                  89
# Community scheme, radiators, oil                                                                         5
# Community scheme, underfloor, mains gas                                                                  5
# Community, community                                                                                    16
# Electric Underfloor Heating (Standard tariff), electric                                                  9
# Electric ceiling                                                                                        12
# Electric ceiling heating                                                                               417
# Electric ceiling heating, electric                                                                      50
# Electric ceiling, electric                                                                              31
# Electric storage heaters                                                                              4749
# Electric storage heaters, Electric storage heaters                                                      11
# Electric storage heaters, radiators                                                                      1
# Electric underfloor heating                                                                           2295
# Electric underfloor heating, Room heaters, electric                                                      2
# Exhaust air MEV source heat pump, Systems with radiators, electric                                      20
# Ground source heat pump , mains gas                                                                      1
# Ground source heat pump, Warm air, electric                                                             12
# Ground source heat pump, fan coil units, electric                                                       23
# Ground source heat pump, radiators, electric                                                            20
# Ground source heat pump, underfloor, electric                                                           23
# Ground source heat pump, underfloor, mains gas                                                           1
# Ground source heat pump, warm air, electric                                                             67
# Ground source heat pump,warm air, electric                                                               6
# Micro-cogeneration, mains gas                                                                            4
# No system present: electric heaters assumed                                                            814
# No system present: electric heaters assumed, mains gas                                                   5
# Portable electric heaters assumed for most rooms                                                        68
# Portable electric heating assumed for most rooms                                                        38
# Radiator heating, electric                                                                               4
# Radiator heating, heat from boilers - gas                                                                1
# Radiator heating, heat from boilers - oil                                                                1
# Room heaters, anthracite                                                                                 1
# Room heaters, bottled LPG                                                                                1
# Room heaters, coal                                                                                       3
# Room heaters, electric                                                                                6988
# Room heaters, electric, Electric underfloor heating                                                      1
# Room heaters, electric, Room heaters, electric                                                           2
# Room heaters, electricity                                                                                8
# Room heaters, mains gas                                                                                226
# Room heaters, oil                                                                                       15
# Room heaters, smokeless fuel                                                                             9
# Room heaters, wood logs                                                                                  1
# SAP05:Main-Heating                                                                                     404
# Warm air , electric                                                                                     16
# Warm air heat pump, electric                                                                             2
# Warm air, Electricaire                                                                                 712
# Warm air, electric                                                                                     152
# Warm air, electricity                                                                                    1
# Warm air, mains gas                                                                                    203
# Warm air, mains gas, Room heaters, electric                                                              1
# Warm air, oil                                                                                            3
# Water source heat pump, fan coil units, electric                                                         7
# Water source heat pump, radiators, electric                                                             13
# Water source heat pump, radiators, mains gas                                                             1
# Water source heat pump, underfloor, electric                                                             1
# Water source heat pump, underfloor, mains gas                                                            1
# Water source heat pump, warm air, electric                                                              45
# Name: UPRN, dtype: int64

# %%
count = geoepcuprn.groupby('MAINS_GAS_FLAG')['UPRN'].count()
print("Frequency of MAINS_GAS_FLAG:\n", count)
# Out:
# Frequency of MAINS_GAS_FLAG:
#  MAINS_GAS_FLAG
# N    25597
# Y    82381
# Name: UPRN, dtype: int64

# %%
total = geoepcuprn.isnull().sum().sort_values(ascending=False)
percent = (geoepcuprn.isnull().sum()/geoepcuprn.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                            Total   Percent
# MAINS_GAS_FLAG             11214  0.094083
# MAIN_FUEL                    491  0.004119
# MAINHEAT_DESCRIPTION           1  0.000008
# POSTCODE                       0  0.000000
# BUILDING_REFERENCE_NUMBER      0  0.000000
# CURRENT_ENERGY_RATING          0  0.000000
# UPRN                           0  0.000000
# X_COORDINATE                   0  0.000000
# Y_COORDINATE                   0  0.000000
# LATITUDE                       0  0.000000
# LONGITUDE                      0  0.000000
# geometry                       0  0.000000

# %%
geoepcuprn.shape
# Out:
# (119192, 12)

# %%
count = geoepcuprn.groupby('CURRENT_ENERGY_RATING')['UPRN'].count()
print("Frequency of CURRENT_ENERGY_RATING:\n", count)
# Out:
# Frequency of CURRENT_ENERGY_RATING:
#  CURRENT_ENERGY_RATING
# A      106
# B    13439
# C    47649
# D    40037
# E    13899
# F     3173
# G      889
# Name: UPRN, dtype: int64

# %%
#geoepcuprn.to_file("energy_rating.geojson", driver="GeoJSON")

# %% [markdown]
# ### MAINHEAT DESCRIPTION MAIN FUEL

# %%
domesticheat = geoepcuprn.copy()

# %%
#Other
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Boiler and radiators, oil.*$)', 'Other(coal,oil,wood,etc.)')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Boiler and underfloor heating, oil.*$)', 'Other(coal,oil,wood,etc.)')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Radiator heating, heat from boilers - oil.*$)', 'Other(coal,oil,wood,etc.)')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Room heaters, anthracite.*$)', 'Other(coal,oil,wood,etc.)')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Room heaters, bottled LPG.*$)', 'Other(coal,oil,wood,etc.)')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Room heaters, coal.*$)', 'Other(coal,oil,wood,etc.)')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Room heaters, oil.*$)', 'Other(coal,oil,wood,etc.)')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Room heaters, wood logs.*$)', 'Other(coal,oil,wood,etc.)')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Room heaters, smokeless fuel.*$)', 'Other(coal,oil,wood,etc.)')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Warm air, oil.*$)', 'Other(coal,oil,wood,etc.)')
# Out:
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/488298725.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/488298725.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/488298725.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/488298725.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/488298725.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/488298725.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/488298725.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/488298725.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/488298725.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/488298725.py:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(

# %%
#heat pump
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Air source heat pump.*$)', 'Heat pump')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Exhaust air MEV.*$)', 'Heat pump')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Ground source heat pump.*$)', 'Heat pump')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Exhaust air MEV.*$)', 'Heat pump')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Water source heat pump.*$)', 'Heat pump')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Warm air heat pump.*$)', 'Heat pump')
# Out:
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/1714152978.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/1714152978.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/1714152978.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/1714152978.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/1714152978.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/1714152978.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(

# %%
#community
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Community.*$)', 'Community')

#Gas (99.7% is gas boiler)
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Boiler.*$)', 'Gas')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Radiator heating, heat from boilers - gas.*$)', 'Gas')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Room heaters, mains gas.*$)', 'Gas')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*SAP05.*$)', 'Gas')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Micro-cogeneration.*$)', 'Gas')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Warm air, mains gas.*$)', 'Gas')

#electric
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Electric.*$)', 'Electric')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*No system present.*$)', 'Electric')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Portable electric.*$)', 'Electric')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Radiator heating, electric.*$)', 'Electric')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Boiler & underfloor, electric.*$)', 'Electric')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Boiler and radiators, electric.*$)', 'Electric')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Boiler and underfloor heating, electric.*$)', 'Electric')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Room heaters, electric.*$)', 'Electric')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Warm air, electric.*$)', 'Electric')
domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
    r'(^.*Warm air , electric.*$)', 'Electric')
# Out:
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:22: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:24: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:26: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:28: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:30: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:32: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:34: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:36: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(
# /var/folders/2v/0j9t8l155ydg312dccl4xxwc0000gn/T/ipykernel_96266/2333108086.py:38: FutureWarning: The default value of regex will change from True to False in a future version.
#   domesticheat['MAINHEAT_DESCRIPTION'] = domesticheat.MAINHEAT_DESCRIPTION.str.replace(

# %%
count = domesticheat.groupby('MAINHEAT_DESCRIPTION')['UPRN'].count()
pd.set_option('display.max_rows', None)  # or 1000
print("Frequency of MAINHEAT_DESCRIPTION:\n", count)
# Out:
# Frequency of MAINHEAT_DESCRIPTION:
#  MAINHEAT_DESCRIPTION
# Community                    32933
# Electric                     16386
# Gas                          67787
# Heat pump                     2043
# Other(coal,oil,wood,etc.)       42
# Name: UPRN, dtype: int64

# %%
count = domesticheat.groupby(['MAINHEAT_DESCRIPTION','CURRENT_ENERGY_RATING'])['UPRN'].count()
pd.set_option('display.max_rows', None)  # or 1000
print("Frequency of MAINHEAT_DESCRIPTION:\n", count)
# Out:
# Frequency of MAINHEAT_DESCRIPTION:
#  MAINHEAT_DESCRIPTION       CURRENT_ENERGY_RATING
# Community                  A                           71
#                            B                         7854
#                            C                        14156
#                            D                         8689
#                            E                         2019
#                            F                          142
#                            G                            2
# Electric                   B                         1030
#                            C                         4087
#                            D                         4637
#                            E                         4014
#                            F                         1861
#                            G                          757
# Gas                        A                           34
#                            B                         3979
#                            C                        28498
#                            D                        26294
#                            E                         7729
#                            F                         1130
#                            G                          123
# Heat pump                  A                            1
#                            B                          566
#                            C                          904
#                            D                          412
#                            E                          130
#                            F                           30
# Other(coal,oil,wood,etc.)  B                           10
#                            C                            4
#                            D                            5
#                            E                            6
#                            F                           10
#                            G                            7
# Name: UPRN, dtype: int64

# %%
domesticheat.shape
# Out:
# (119192, 12)

# %%
domesticheat = domesticheat.dropna(subset=['MAINHEAT_DESCRIPTION'])
domesticheat.shape
# Out:
# (119191, 12)

# %%
domesticheat.head(3)
# Out:
#   POSTCODE  BUILDING_REFERENCE_NUMBER CURRENT_ENERGY_RATING MAINS_GAS_FLAG  \
# 0   W2 6DE                 5917607278                     C              Y
# 1   W9 1LF                 7273449668                     D              Y
# 2  W1G 8TJ                 9110917378                     B              Y
#
#   MAINHEAT_DESCRIPTION                                          MAIN_FUEL  \
# 0                  Gas                          mains gas (not community)
# 1                  Gas  mains gas - this is for backwards compatibilit...
# 2                  Gas                          mains gas (not community)
#
#            UPRN  X_COORDINATE  Y_COORDINATE   LATITUDE  LONGITUDE  \
# 0  1.003357e+10      526138.0      181113.0  51.514869  -0.183545
# 1  1.000228e+11      525493.0      182598.0  51.528359  -0.192306
# 2  1.003363e+10      528530.0      181625.0  51.518932  -0.148905
#
#                         geometry
# 0  POINT (526139.702 181113.208)
# 1  POINT (525494.713 182598.249)
# 2  POINT (528531.743 181625.233)

# %%
heatpump = domesticheat.loc[domesticheat['MAINHEAT_DESCRIPTION'] == 'Heat pump']
heatpump.shape
# Out:
# (2043, 12)

# %%
heatpump.to_file("heatpump.geojson", driver="GeoJSON")

# %%
newdomesticheat = domesticheat.replace(
    to_replace =["Community"], value = "District Heating").replace(
    to_replace =["Electric"], value = "Electricity").replace(
    to_replace =["Gas"], value = "Natural Gas").replace(
    to_replace =["Other(coal,oil,wood,etc.)"], value = "Other (Oil, LPG, Coal, etc.)").replace(
    to_replace =["Heat pump"], value = "Electricity").copy()

# %%
count = newdomesticheat.groupby('MAINHEAT_DESCRIPTION')['UPRN'].count()
pd.set_option('display.max_rows', None)  # or 1000
print("Frequency of MAINHEAT_DESCRIPTION:\n", count)
# Out:
# Frequency of MAINHEAT_DESCRIPTION:
#  MAINHEAT_DESCRIPTION
# District Heating                32933
# Electricity                     18429
# Natural Gas                     67787
# Other (Oil, LPG, Coal, etc.)       42
# Name: UPRN, dtype: int64

# %%
#newdomesticheat.to_file("newdomesticheat.geojson", driver="GeoJSON")

# %% [markdown]
# ### MAINS GAS FLAG

# %%
gasflag = geoepcuprn.dropna(subset=['MAINS_GAS_FLAG'])
gasflag.shape
# Out:
# (107978, 12)

# %%
gasyes = gasflag.loc[gasflag['MAINS_GAS_FLAG'] == 'Y']
gasyes.shape
# Out:
# (82381, 12)

# %%
gasyes.head(3)
# Out:
#   POSTCODE  BUILDING_REFERENCE_NUMBER CURRENT_ENERGY_RATING MAINS_GAS_FLAG  \
# 0   W2 6DE                 5917607278                     C              Y
# 1   W9 1LF                 7273449668                     D              Y
# 2  W1G 8TJ                 9110917378                     B              Y
#
#                        MAINHEAT_DESCRIPTION  \
# 0           Boiler and radiators, mains gas
# 1           Boiler and radiators, mains gas
# 2  Boiler and underfloor heating, mains gas
#
#                                            MAIN_FUEL          UPRN  \
# 0                          mains gas (not community)  1.003357e+10
# 1  mains gas - this is for backwards compatibilit...  1.000228e+11
# 2                          mains gas (not community)  1.003363e+10
#
#    X_COORDINATE  Y_COORDINATE   LATITUDE  LONGITUDE  \
# 0      526138.0      181113.0  51.514869  -0.183545
# 1      525493.0      182598.0  51.528359  -0.192306
# 2      528530.0      181625.0  51.518932  -0.148905
#
#                         geometry
# 0  POINT (526139.702 181113.208)
# 1  POINT (525494.713 182598.249)
# 2  POINT (528531.743 181625.233)

# %%
#gasyes.to_file("gasyes.geojson", driver="GeoJSON")

# %%
gasno = gasflag.loc[gasflag['MAINS_GAS_FLAG'] == 'N']
gasno.shape
# Out:
# (25597, 12)

# %%
#gasno.to_file("gasno.geojson", driver="GeoJSON")

# %% [markdown]
# ### MAINHEAT DESCRIPTION

# %%
mainheat = = geoepcuprn.replace(
    to_replace =["mechanical, supply and extract"], value = "MVHR").replace(
    to_replace =["mechanical, extract only"], value = "MEV").copy()
ahouse.MECHANICAL_VENTILATION.unique()

mainfuel = geoepcuprn.replace(
    to_replace =["mechanical, supply and extract"], value = "MVHR").replace(
    to_replace =["mechanical, extract only"], value = "MEV").copy()
ahouse.MECHANICAL_VENTILATION.unique()
